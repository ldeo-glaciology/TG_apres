# %%
from rechunker import rechunk
from dask.diagnostics import ProgressBar
# %load_ext autoreload
# %autoreload 2 
import sys
sys.path.append("/home/jovyan/xapres/")
import xapres as xa
import numpy as np
import xarray as xr
import zarr
import os
import json
import fsspec
import hvplot.xarray
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
def load_zarr(f):
    return xr.open_dataset(f, engine = 'zarr', chunks = {})

# %%
ds1 = load_zarr('zarrs/ApRES_Lake2_1')
ds2 = load_zarr('zarrs/ApRES_Lake2_2')

# %%
ds1.isel(time=slice(0,3)).to_zarr('zarrs/appending_tests/ds1_3')

# %%
ds1.isel(time=slice(3,5)).to_zarr('zarrs/appending_tests/ds1_3', append_dim = 'time')

# %%
ds1.isel(time=slice(3,5))
# Out:
# <xarray.Dataset> Size: 128MB
# Dimensions:          (attenuator_setting_pair: 1, time: 2, chirp_time: 40001,
#                       chirp_num: 200)
# Coordinates:
#     AFGain           (attenuator_setting_pair) int64 8B dask.array<chunksize=(1,), meta=np.ndarray>
#     attenuator       (attenuator_setting_pair) float64 8B dask.array<chunksize=(1,), meta=np.ndarray>
#     burst_number     (time) int64 16B dask.array<chunksize=(2,), meta=np.ndarray>
#   * chirp_num        (chirp_num) int64 2kB 0 1 2 3 4 5 ... 195 196 197 198 199
#   * chirp_time       (chirp_time) timedelta64[ns] 320kB 00:00:00 ... 00:00:01
#     filename         (time) <U92 736B dask.array<chunksize=(2,), meta=np.ndarray>
#     orientation      (time) <U7 56B dask.array<chunksize=(2,), meta=np.ndarray>
#   * time             (time) datetime64[ns] 16B 2023-01-19T06:20:25 2023-01-20...
# Dimensions without coordinates: attenuator_setting_pair
# Data variables:
# ...

# %%
ds1.isel(time=[6])
# Out:
# <xarray.Dataset> Size: 64MB
# Dimensions:          (attenuator_setting_pair: 1, time: 1, chirp_time: 40001,
#                       chirp_num: 200)
# Coordinates:
#     AFGain           (attenuator_setting_pair) int64 8B dask.array<chunksize=(1,), meta=np.ndarray>
#     attenuator       (attenuator_setting_pair) float64 8B dask.array<chunksize=(1,), meta=np.ndarray>
#     burst_number     (time) int64 8B dask.array<chunksize=(1,), meta=np.ndarray>
#   * chirp_num        (chirp_num) int64 2kB 0 1 2 3 4 5 ... 195 196 197 198 199
#   * chirp_time       (chirp_time) timedelta64[ns] 320kB 00:00:00 ... 00:00:01
#     filename         (time) <U92 368B dask.array<chunksize=(1,), meta=np.ndarray>
#     orientation      (time) <U7 28B dask.array<chunksize=(1,), meta=np.ndarray>
#   * time             (time) datetime64[ns] 8B 2023-01-22T06:20:56
# Dimensions without coordinates: attenuator_setting_pair
# Data variables:
# ...

# %%
ds1_01 = load_zarr('zarrs/appending_tests/ds1_3')
ds1_01
# Out:
# <xarray.Dataset> Size: 320MB
# Dimensions:          (attenuator_setting_pair: 1, time: 5, chirp_time: 40001,
#                       chirp_num: 200)
# Coordinates:
#     AFGain           (attenuator_setting_pair) int64 8B dask.array<chunksize=(1,), meta=np.ndarray>
#     attenuator       (attenuator_setting_pair) float64 8B dask.array<chunksize=(1,), meta=np.ndarray>
#     burst_number     (time) int64 40B dask.array<chunksize=(5,), meta=np.ndarray>
#   * chirp_num        (chirp_num) int64 2kB 0 1 2 3 4 5 ... 195 196 197 198 199
#   * chirp_time       (chirp_time) timedelta64[ns] 320kB 00:00:00 ... 00:00:01
#     filename         (time) <U92 2kB dask.array<chunksize=(5,), meta=np.ndarray>
#     orientation      (time) <U7 140B dask.array<chunksize=(5,), meta=np.ndarray>
#   * time             (time) datetime64[ns] 40B 2023-01-16T06:20:39 ... 2023-0...
# Dimensions without coordinates: attenuator_setting_pair
# Data variables:
# ...
